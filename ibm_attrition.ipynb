# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('../Datasets/IBM_attrition_.csv')

# %%
df
# Out:
#       Age  Attrition          Business../Travel  DailyRate  \
# 0      41          1  Travel_Rarely/Travel_less       1102
# 1      49          0          Travel_Frequently        279
# 2      37          1  Travel_Rarely/Travel_less       1373
# 3      33          0          Travel_Frequently       1392
# 4      27          0  Travel_Rarely/Travel_less        591
# ...   ...        ...                        ...        ...
# 1465   36          0          Travel_Frequently        884
# 1466   39          0  Travel_Rarely/Travel_less        613
# 1467   27          0  Travel_Rarely/Travel_less        155
# 1468   49          0          Travel_Frequently       1023
# 1469   34          0  Travel_Rarely/Travel_less        628
#
#                         Department  DistanceFromHome  Education  \
# 0                            Sales                 1          2
# 1     Research & Development / R&D                 8          1
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'Business../Travel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'Environment\Satisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'Num\Companies_Worked',
#        'Over18', 'OverTime', 'Percent\Salary\Hike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'Training\..Times_LastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.select_dtypes(include ='object').columns
# Out:
# Index(['Business../Travel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Age                          0
# Attrition                    0
# Business../Travel            0
# DailyRate                    0
# Department                   0
# DistanceFromHome             0
# Education                    0
# EducationField               0
# EmployeeCount                0
# EmployeeNumber               0
# Environment\Satisfaction     0
# Gender                       0
# HourlyRate                   0
# JobInvolvement               0
# JobLevel                     0
# JobRole                      0
# JobSatisfaction              0
# MaritalStatus                0
# MonthlyIncome                0
# MonthlyRate                  0
# Num\Companies_Worked         0
# Over18                       0
# OverTime                     0
# Percent\Salary\Hike          0
# PerformanceRating            0
# RelationshipSatisfaction     0
# StandardHours                0
# StockOptionLevel             0
# TotalWorkingYears            0
# Training\..Times_LastYear    0
# ...

# %%
df=df.rename(columns={"Environment\Satisfaction":"Environment_Satisfaction"})
df=df.rename(columns={"Percent\salary\Hike":"Salary_Hike"})
df=df.rename(columns={"Training\..Times_LastYear":"Training_LastYear"})
df=df.rename(columns={"Num\Companies_Worked":"Num_Companies_Worked"})
df=df.rename(columns={"Business../Travel":"Business_Travel"})

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                    int64
# Business_Travel             object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# Environment_Satisfaction     int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# Num_Companies_Worked         int64
# Over18                      object
# OverTime                    object
# Percent\Salary\Hike          int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.Business_Travel.value_counts()
# Out:
# Business_Travel
# Travel_Rarely/Travel_less    1043
# Travel_Frequently             277
# Non-Travel                    150
# Name: count, dtype: int64

# %%
df.OverTime.value_counts()
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
df.Department.value_counts()
# Out:
# Department
# Research & Development / R&D    961
# Sales                           446
# Human Resources / HR             63
# Name: count, dtype: int64

# %%
df.EducationField.value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'Business_Travel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'Environment_Satisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'Num_Companies_Worked',
#        'Over18', 'OverTime', 'Percent\Salary\Hike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'Training_LastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.groupby('Department')['Attrition'].mean()
# Out:
# Department
# Human Resources / HR            0.190476
# Research & Development / R&D    0.138398
# Sales                           0.206278
# Name: Attrition, dtype: float64

# %%
df.groupby('JobRole')['Attrition'].mean()
# Out:
# JobRole
# Healthcare Representative    0.068702
# Human Resources              0.230769
# Laboratory Technician        0.239382
# Manager                      0.049020
# Manufacturing Director       0.068966
# Research Director            0.025000
# Research Scientist           0.160959
# Sales Executive              0.174847
# Sales Representative         0.397590
# Name: Attrition, dtype: float64

# %%
df.groupby('Gender')['Attrition'].mean()
# Out:
# Gender
# Female    0.147959
# Male      0.170068
# Name: Attrition, dtype: float64

# %%
df.groupby('OverTime')['Attrition'].mean()
# Out:
# OverTime
# No     0.104364
# Yes    0.305288
# Name: Attrition, dtype: float64

# %%
pd.pivot_table(df, index='Department', columns='JobRole', values='Attrition', margins='True')
# Out:
# JobRole                       Healthcare Representative  Human Resources  \
# Department
# Human Resources / HR                                NaN         0.230769
# Research & Development / R&D                   0.068702              NaN
# Sales                                               NaN              NaN
# All                                            0.068702         0.230769
#
# JobRole                       Laboratory Technician   Manager  \
# Department
# Human Resources / HR                            NaN  0.000000
# Research & Development / R&D               0.239382  0.055556
# Sales                                           NaN  0.054054
# All                                        0.239382  0.049020
#
# JobRole                       Manufacturing Director  Research Director  \
# Department
# Human Resources / HR                             NaN                NaN
# Research & Development / R&D                0.068966              0.025
# ...

# %%
pd.pivot_table(df, index='OverTime', columns='JobRole', values='Attrition', margins='True')
# Out:
# JobRole   Healthcare Representative  Human Resources  Laboratory Technician  \
# OverTime
# No                         0.074468         0.179487               0.157360
# Yes                        0.054054         0.384615               0.500000
# All                        0.068702         0.230769               0.239382
#
# JobRole    Manager  Manufacturing Director  Research Director  \
# OverTime
# No        0.013333                0.056604           0.017544
# Yes       0.148148                0.102564           0.043478
# All       0.049020                0.068966           0.025000
#
# JobRole   Research Scientist  Sales Executive  Sales Representative       All
# OverTime
# No                  0.071795         0.112069              0.288136  0.104364
# Yes                 0.340206         0.329787              0.666667  0.305288
# All                 0.160959         0.174847              0.397590  0.161224

# %%
pd.pivot_table(df, index='Gender', columns='JobRole', values='Attrition', margins='True')
# Out:
# JobRole  Healthcare Representative  Human Resources  Laboratory Technician  \
# Gender
# Female                    0.098039         0.375000               0.188235
# Male                      0.050000         0.166667               0.264368
# All                       0.068702         0.230769               0.239382
#
# JobRole   Manager  Manufacturing Director  Research Director  \
# Gender
# Female   0.042553                0.055556           0.030303
# Male     0.054545                0.082192           0.021277
# All      0.049020                0.068966           0.025000
#
# JobRole  Research Scientist  Sales Executive  Sales Representative       All
# Gender
# Female             0.149123         0.151515              0.421053  0.147959
# Male               0.168539         0.190722              0.377778  0.170068
# All                0.160959         0.174847              0.397590  0.161224

# %%
sb.countplot(x='Gender',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sb.histplot(x='Age',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sb.countplot(x='Department',data=df)
plt.xticks(rotation=15)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'Sales'),
#   Text(1, 0, 'Research & Development / R&D'),
#   Text(2, 0, 'Human Resources / HR')])

# %%
df.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  Environment_Satisfaction   HourlyRate  \
# count         1470.0     1470.000000               1470.000000  1470.000000
# mean             1.0     1024.865306                  2.721769    65.891156
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                                Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000000  -0.159205   0.010661         -0.001686
# Attrition                -0.159205   1.000000  -0.056652          0.077924
# DailyRate                 0.010661  -0.056652   1.000000         -0.004985
# DistanceFromHome         -0.001686   0.077924  -0.004985          1.000000
# Education                 0.208034  -0.031373  -0.016806          0.021042
# EmployeeCount                  NaN        NaN        NaN               NaN
# EmployeeNumber           -0.010145  -0.010577  -0.050990          0.032916
# Environment_Satisfaction  0.010146  -0.103369   0.018355         -0.016075
# HourlyRate                0.024287  -0.006846   0.023381          0.031131
# JobInvolvement            0.029820  -0.130016   0.046135          0.008783
# JobLevel                  0.509604  -0.169105   0.002966          0.005303
# ...

# %%
sb.pairplot(df[['Age','MonthlyIncome','TotalWorkingYears','YearsAtCompany','DistanceFromHome']])
plt.show()

# %%
print(df.Department.unique())
d=input("enter department name")
dd=df [df.Department==d]

print(dd.JobRole.unique())
j=input("enter job role")
jj=dd[dd.JobRole==j]

print(jj.OverTime.unique())
o=input("enter overtime ")
oo=jj[jj.OverTime==o]
q=oo.groupby('JobRole') ['Attrition'].mean()
sb.barplot(q)
plt.show()
# Out:
# ['Sales' 'Research & Development / R&D' 'Human Resources / HR']
# enter department name Sales
# ['Sales Executive' 'Manager' 'Sales Representative']
# enter job role Manager
# ['No' 'Yes']
# enter overtime  No

# %%
sb.barplot(data=df,x='JobRole',y='Attrition')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Sales Executive'),
#   Text(1, 0, 'Research Scientist'),
#   Text(2, 0, 'Laboratory Technician'),
#   Text(3, 0, 'Manufacturing Director'),
#   Text(4, 0, 'Healthcare Representative'),
#   Text(5, 0, 'Manager'),
#   Text(6, 0, 'Sales Representative'),
#   Text(7, 0, 'Research Director'),
#   Text(8, 0, 'Human Resources')])

# %%
Job_Attrition=df.groupby('JobRole')['Attrition'].mean()

# %%
sb.barplot(x=Job_Attrition.index,y=Job_Attrition.values)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Healthcare Representative'),
#   Text(1, 0, 'Human Resources'),
#   Text(2, 0, 'Laboratory Technician'),
#   Text(3, 0, 'Manager'),
#   Text(4, 0, 'Manufacturing Director'),
#   Text(5, 0, 'Research Director'),
#   Text(6, 0, 'Research Scientist'),
#   Text(7, 0, 'Sales Executive'),
#   Text(8, 0, 'Sales Representative')])

# %%
sb.barplot(data=df, x='Department', y='Attrition')
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'Sales'),
#   Text(1, 0, 'Research & Development / R&D'),
#   Text(2, 0, 'Human Resources / HR')])

# %%
sb.barplot(data=df, x='Gender', y='Attrition')
# Out:
# <Axes: xlabel='Gender', ylabel='Attrition'>

# %%
sb.barplot(data=df, x='OverTime', y='Attrition')
# Out:
# <Axes: xlabel='OverTime', ylabel='Attrition'>
